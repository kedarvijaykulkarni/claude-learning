# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Key criteria for evaluating the solution"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Criteria you should use to evaluate the solution:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 8.333333333333334

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\n{\n  \"FunctionName\": \"S3EventProcessor\",\n  \"Runtime\": \"python3.11\",\n  \"Role\": \"arn:aws:iam::ACCOUNT_ID:role/lambda-execution-role\",\n  \"Handler\": \"index.lambda_handler\",\n  \"Timeout\": 60,\n  \"MemorySize\": 256,\n  \"Environment\": {\n    \"Variables\": {\n      \"SNS_TOPIC_ARN\": \"arn:aws:sns:us-east-1:ACCOUNT_ID:s3-events-topic\",\n      \"LOG_LEVEL\": \"INFO\"\n    }\n  },\n  \"Events\": {\n    \"S3Event\": {\n      \"Type\": \"S3\",\n      \"Properties\": {\n        \"Bucket\": \"my-bucket\",\n        \"Events\": [\n          \"s3:ObjectCreated:*\",\n          \"s3:ObjectRemoved:*\"\n        ],\n        \"Filter\": {\n          \"Key\": {\n            \"FilterRules\": [\n              {\n                \"Name\": \"prefix\",\n                \"Value\": \"uploads/\"\n              },\n              {\n                \"Name\": \"suffix\",\n                \"Value\": \".json\"\n              }\n            ]\n          }\n        }\n      }\n    }\n  },\n  \"VpcConfig\": {\n    \"SecurityGroupIds\": [],\n    \"SubnetIds\": []\n  },\n  \"Tags\": {\n    \"Environment\": \"production\",\n    \"Application\": \"s3-event-processor\"\n  }\n}\n",
#     "test_case": {
#       "task": "Create a JSON configuration object for an AWS Lambda function that processes S3 events, with environment variables for the target SNS topic ARN and logging level",
#       "format": "json",
#       "solution_criteria": "Must include valid Lambda function properties (Handler, Runtime, Role), environment variables section with SNS_TOPIC_ARN and LOG_LEVEL, and S3 event trigger configuration"
#     },
#     "score": 8.5,
#     "reasoning": "The solution demonstrates solid understanding of Lambda configuration requirements and includes all mandatory elements specified in the criteria. The environment variables are correctly structured, and the S3 event trigger includes thoughtful filtering. However, there is a critical format issue: the 'Events' section uses CloudFormation/SAM template syntax, which is appropriate for infrastructure-as-code tools but not for direct AWS Lambda API calls. For a pure Lambda JSON configuration object (as requested), S3 event source mapping should be configured separately via CreateEventSourceMapping API or defined in infrastructure-as-code syntax appropriately. The solution would work in CloudFormation/SAM context but may cause confusion regarding its intended use case."
#   },
#   {
#     "output": "\nimport re\n\ndef get_s3_uri(bucket_name: str, object_key: str) -> str:\n    return f\"s3://{bucket_name}/{object_key}\"\n",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS S3 bucket name and object key as parameters and returns the S3 URI in the format 's3://bucket-name/object-key'",
#       "format": "python",
#       "solution_criteria": "Function must accept two string parameters, properly format the S3 URI, handle edge cases like trailing slashes, and return a valid S3 URI string"
#     },
#     "score": 8.0,
#     "reasoning": "The solution meets the basic requirement of formatting an S3 URI, but falls short on robustness. It lacks input validation for empty or None values, doesn't normalize trailing slashes as mentioned in the criteria, and includes an unnecessary regex import. For production use, the function should validate inputs and handle common edge cases like leading/trailing slashes in the object_key parameter."
#   },
#   {
#     "output": "\n^arn:aws:iam::\\d{12}:role/[a-zA-Z0-9_-]+$\n",
#     "test_case": {
#       "task": "Create a regular expression that matches valid AWS IAM role ARNs in the format: arn:aws:iam::account-id:role/role-name, where account-id is 12 digits and role-name contains alphanumerics, hyphens, and underscores",
#       "format": "regex",
#       "solution_criteria": "Regex must match valid IAM role ARNs, reject invalid formats, correctly validate 12-digit account IDs, and allow alphanumeric characters, hyphens, and underscores in role names"
#     },
#     "score": 8.5,
#     "reasoning": "The regex correctly implements the core requirements: matching the ARN format, validating the 12-digit account ID, and allowing proper characters in role names. The anchors prevent false positives. However, it lacks validation for role name length limits per AWS specifications, and the character class could be more explicit about minimum length requirements. These are minor gaps that don't prevent basic functionality but reduce robustness for production use."
#   }
# ]
