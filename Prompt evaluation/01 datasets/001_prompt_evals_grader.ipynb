# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 7

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# Parse AWS S3 Bucket Name\n\nHere's a solution to extract the bucket name from an S3 URI:\n\n```python\ndef parse_s3_bucket_name(s3_uri: str) -> str:\n    \"\"\"\n    Extract bucket name from an S3 URI.\n    \n    Args:\n        s3_uri: S3 URI in format 's3://bucket-name/path/to/file'\n        \n    Returns:\n        The bucket name\n        \n    Raises:\n        ValueError: If the URI format is invalid\n    \"\"\"\n    if not s3_uri.startswith('s3://'):\n        raise ValueError(f\"Invalid S3 URI format: {s3_uri}\")\n    \n    # Remove 's3://' prefix and split by '/'\n    parts = s3_uri[5:].split('/', 1)\n    bucket_name = parts[0]\n    \n    if not bucket_name:\n        raise ValueError(\"Bucket name cannot be empty\")\n    \n    return bucket_name\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_cases = [\n        \"s3://my-bucket/path/to/file.txt\",\n        \"s3://another-bucket/file.json\",\n        \"s3://my-bucket-123/deep/nested/path/to/data.csv\",\n        \"s3://bucket\",  # No path\n    ]\n    \n    for uri in test_cases:\n        bucket = parse_s3_bucket_name(uri)\n        print(f\"{uri} \u2192 {bucket}\")\n```\n\n**Output:**\n```\ns3://my-bucket/path/to/file.txt \u2192 my-bucket\ns3://another-bucket/file.json \u2192 another-bucket\ns3://my-bucket-123/deep/nested/path/to/data.csv \u2192 my-bucket-123\ns3://bucket \u2192 bucket\n```\n\n## Alternative Solutions\n\n**Using regex:**\n```python\nimport re\n\ndef parse_s3_bucket_name(s3_uri: str) -> str:\n    match = re.match(r's3://([^/]+)', s3_uri)\n    if not match:\n        raise ValueError(f\"Invalid S3 URI format: {s3_uri}\")\n    return match.group(1)\n```\n\n**Using urllib:**\n```python\nfrom urllib.parse import urlparse\n\ndef parse_s3_bucket_name(s3_uri: str) -> str:\n    parsed = urlparse(s3_uri)\n    if parsed.scheme != 's3':\n        raise ValueError(f\"Invalid S3 URI format: {s3_uri}\")\n    return parsed.netloc\n```\n\nAll three approaches handle the S3 URI format correctly and return just the bucket name!",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from an S3 URI (e.g., 's3://my-bucket/path/to/file.txt') and extract just the bucket name",
#       "format": "regex"
#     },
#     "score": 7,
#     "reasoning": "The solution correctly solves the stated task with functional implementations and good code quality. However, it lacks AWS S3-specific validation that would be expected in production code. The primary solution (string splitting) works but is less robust than urllib.parse for URL parsing. The alternatives are good to show, but the recommendation order could be clearer. For a real AWS application, adding bucket name validation against S3 constraints would significantly improve the solution."
#   },
#   {
#     "output": "# AWS Lambda Function JSON Configuration\n\n```json\n{\n  \"FunctionName\": \"my-lambda-function\",\n  \"Runtime\": \"python3.11\",\n  \"Role\": \"arn:aws:iam::ACCOUNT_ID:role/lambda-execution-role\",\n  \"Handler\": \"index.handler\",\n  \"Timeout\": 30,\n  \"MemorySize\": 256,\n  \"Description\": \"Lambda function with Python 3.11 runtime\",\n  \"Environment\": {\n    \"Variables\": {}\n  },\n  \"Tags\": {\n    \"Environment\": \"production\",\n    \"Project\": \"my-project\"\n  }\n}\n```\n\n## Key Configuration Properties:\n\n| Property | Value | Description |\n|----------|-------|-------------|\n| **Runtime** | `python3.11` | Python 3.11 runtime environment |\n| **MemorySize** | `256` | Memory allocation in MB (128-10,240 MB) |\n| **Timeout** | `30` | Maximum execution time in seconds |\n| **Handler** | `index.handler` | Entry point for Lambda execution |\n| **Role** | IAM ARN | Execution role with necessary permissions |\n\n## Minimal Configuration:\n\nIf you only need the three specified properties:\n\n```json\n{\n  \"Runtime\": \"python3.11\",\n  \"MemorySize\": 256,\n  \"Timeout\": 30\n}\n```\n\nThis configuration will create a Lambda function that runs Python 3.11 code with 256 MB of memory and a maximum timeout of 30 seconds.",
#     "test_case": {
#       "task": "Create a JSON configuration object for an AWS Lambda function that specifies runtime as 'python3.11', memory as 256 MB, and timeout as 30 seconds",
#       "format": "json"
#     },
#     "score": 7,
#     "reasoning": "The solution correctly addresses the core task requirements with accurate AWS parameter names and values. The inclusion of a minimal configuration section directly answers the stated need. However, the presentation conflates optional configuration properties with required ones, and the full example uses placeholders without clear explanation that these are not part of the three specified requirements. The documentation is helpful but could be clearer about distinguishing between required vs. optional fields."
#   },
#   {
#     "output": "# AWS IAM Policy Wildcard Action Extractor\n\nHere's a Python function that extracts all AWS actions with wildcard resources from an IAM policy document:\n\n```python\ndef get_wildcard_actions(policy_doc):\n    \"\"\"\n    Extract all AWS actions that have wildcard ('*') resources from an IAM policy document.\n    \n    Args:\n        policy_doc (dict): An AWS IAM policy document as a dictionary\n        \n    Returns:\n        list: A list of action strings (e.g., ['s3:GetObject', 'iam:*'])\n    \"\"\"\n    wildcard_actions = []\n    \n    # Handle missing or invalid policy\n    if not isinstance(policy_doc, dict):\n        return wildcard_actions\n    \n    # Get the Statement array from the policy\n    statements = policy_doc.get('Statement', [])\n    \n    if not isinstance(statements, list):\n        return wildcard_actions\n    \n    for statement in statements:\n        if not isinstance(statement, dict):\n            continue\n            \n        # Get Resource(s) from the statement\n        resources = statement.get('Resource', [])\n        \n        # Normalize resources to a list\n        if isinstance(resources, str):\n            resources = [resources]\n        elif not isinstance(resources, list):\n            continue\n        \n        # Check if resources contain wildcard\n        has_wildcard_resource = '*' in resources\n        \n        if has_wildcard_resource:\n            # Get Action(s) from the statement\n            actions = statement.get('Action', [])\n            \n            # Normalize actions to a list\n            if isinstance(actions, str):\n                actions = [actions]\n            elif not isinstance(actions, list):\n                continue\n            \n            # Add all actions from this statement\n            wildcard_actions.extend(actions)\n    \n    # Remove duplicates while preserving order\n    seen = set()\n    result = []\n    for action in wildcard_actions:\n        if action not in seen:\n            seen.add(action)\n            result.append(action)\n    \n    return result\n\n\n# Example usage and test cases\nif __name__ == \"__main__\":\n    # Test case 1: Simple policy with wildcard resource\n    policy1 = {\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": \"s3:GetObject\",\n                \"Resource\": \"*\"\n            }\n        ]\n    }\n    print(\"Test 1:\", get_wildcard_actions(policy1))\n    # Output: ['s3:GetObject']\n    \n    # Test case 2: Multiple actions with wildcard resource\n    policy2 = {\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": [\"s3:GetObject\", \"s3:PutObject\"],\n                \"Resource\": \"*\"\n            }\n        ]\n    }\n    print(\"Test 2:\", get_wildcard_actions(policy2))\n    # Output: ['s3:GetObject', 's3:PutObject']\n    \n    # Test case 3: Mixed - some with wildcard, some without\n    policy3 = {\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": \"s3:GetObject\",\n                \"Resource\": \"*\"\n            },\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": \"s3:DeleteObject\",\n                \"Resource\": \"arn:aws:s3:::my-bucket/*\"\n            }\n        ]\n    }\n    print(\"Test 3:\", get_wildcard_actions(policy3))\n    # Output: ['s3:GetObject']\n    \n    # Test case 4: Wildcard action with wildcard resource\n    policy4 = {\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": \"*\",\n                \"Resource\": \"*\"\n            }\n        ]\n    }\n    print(\"Test 4:\", get_wildcard_actions(policy4))\n    # Output",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS IAM policy document (as a dict) and returns a list of all AWS actions (e.g., 's3:GetObject') that have a wildcard resource ('*')",
#       "format": "python"
#     },
#     "score": 7,
#     "reasoning": "The solution correctly implements the core requirement of extracting actions with wildcard resources from IAM policies. The code is defensive with good error handling and type normalization. However, it has gaps in AWS IAM policy completeness (NotResource, Deny statements) and test coverage. The logic is sound for the basic use case but lacks robustness for production-grade AWS policy analysis. The deduplication implementation is correct and efficient."
#   }
# ]
